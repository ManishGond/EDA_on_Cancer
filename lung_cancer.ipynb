# %% [markdown]
# <a href="https://colab.research.google.com/github/ManishGond/EDA_on_Cancer/blob/main/lung_cancer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv('lung_cancer.csv')

# %%
data
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
data.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# ...

# %%
data.tail()
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 304                2         2         1         1                  2
# 305                1         2         2         2                  2
# 306                1         1         2         2                  2
# 307                1         2         2         1                  2
# 308                1         2         2         2                  2
#
#      COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  \
# 304         2                    2                      2           1
# ...

# %%
data.shape
# Out:
# (309, 16)

# %%
data.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC DISEASE', 'FATIGUE ', 'ALLERGY ', 'WHEEZING',
#        'ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH',
#        'SWALLOWING DIFFICULTY', 'CHEST PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 309 non-null    object
#  1   AGE                    309 non-null    int64
#  2   SMOKING                309 non-null    int64
#  3   YELLOW_FINGERS         309 non-null    int64
#  4   ANXIETY                309 non-null    int64
#  5   PEER_PRESSURE          309 non-null    int64
#  6   CHRONIC DISEASE        309 non-null    int64
#  7   FATIGUE                309 non-null    int64
#  8   ALLERGY                309 non-null    int64
#  9   WHEEZING               309 non-null    int64
#  10  ALCOHOL CONSUMING      309 non-null    int64
#  11  COUGHING               309 non-null    int64
#  12  SHORTNESS OF BREATH    309 non-null    int64
#  13  SWALLOWING DIFFICULTY  309 non-null    int64
#  14  CHEST PAIN             309 non-null    int64
# ...

# %%
data.isnull().sum()
# Out:
# GENDER                   0
# AGE                      0
# SMOKING                  0
# YELLOW_FINGERS           0
# ANXIETY                  0
# PEER_PRESSURE            0
# CHRONIC DISEASE          0
# FATIGUE                  0
# ALLERGY                  0
# WHEEZING                 0
# ALCOHOL CONSUMING        0
# COUGHING                 0
# SHORTNESS OF BREATH      0
# SWALLOWING DIFFICULTY    0
# CHEST PAIN               0
# LUNG_CANCER              0
# dtype: int64

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 304     True
# 305     True
# 306     True
# 307     True
# 308     True
# Length: 309, dtype: bool

# %%
data[data.duplicated()]
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 99       M   56        2               1        1              1
# 100      M   58        2               1        1              1
# 117      F   51        2               2        2              2
# 199      F   55        2               1        1              2
# 212      M   58        2               1        1              1
# 223      M   63        2               2        2              1
# 256      M   60        2               1        1              1
# 275      M   64        2               2        2              2
# 284      M   58        2               2        2              2
# 285      F   58        2               2        2              2
# 286      F   63        1               1        1              1
# 287      F   51        2               2        2              2
# 288      F   61        1               2        2              2
# ...

# %%
new_data = data.drop_duplicates()

# %%
new_data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 279    False
# 280    False
# 281    False
# 282    False
# 283    False
# Length: 276, dtype: bool

# %%
new_data.shape
# Out:
# (276, 16)

# %%
data.shape
# Out:
# (309, 16)

# %%
data['GENDER']
# Out:
# 0      M
# 1      M
# 2      F
# 3      M
# 4      F
#       ..
# 304    F
# 305    M
# 306    M
# 307    M
# 308    M
# Name: GENDER, Length: 309, dtype: object

# %%
new_data['GENDER']=new_data['GENDER'].map({'M':1,'F':0})
# Out:
# <ipython-input-56-0615f84b88fc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['GENDER']=new_data['GENDER'].map({'M':1,'F':0})

# %%
new_data['GENDER']
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 279    0
# 280    0
# 281    1
# 282    1
# 283    1
# Name: GENDER, Length: 276, dtype: int64

# %%
new_data
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         1   69        1               2        2              1
# 1         1   74        2               1        1              1
# 2         0   59        1               1        1              2
# 3         1   63        2               2        2              1
# 4         0   63        1               2        1              1
# ..      ...  ...      ...             ...      ...            ...
# 279       0   59        1               2        2              2
# 280       0   59        2               1        1              1
# 281       1   55        2               1        1              1
# 282       1   46        1               2        2              1
# 283       1   60        1               2        2              1
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
new_data['LUNG_CANCER']
# Out:
# 0      YES
# 1      YES
# 2       NO
# 3       NO
# 4       NO
#       ...
# 279    YES
# 280     NO
# 281     NO
# 282     NO
# 283    YES
# Name: LUNG_CANCER, Length: 276, dtype: object

# %%
new_data.describe()
# Out:
#            GENDER         AGE     SMOKING  YELLOW_FINGERS     ANXIETY  \
# count  276.000000  276.000000  276.000000      276.000000  276.000000
# mean     0.514493   62.909420    1.543478        1.576087    1.496377
# std      0.500698    8.379355    0.499011        0.495075    0.500895
# min      0.000000   21.000000    1.000000        1.000000    1.000000
# 25%      0.000000   57.750000    1.000000        1.000000    1.000000
# 50%      1.000000   62.500000    2.000000        2.000000    1.000000
# 75%      1.000000   69.000000    2.000000        2.000000    2.000000
# max      1.000000   87.000000    2.000000        2.000000    2.000000
#
#        PEER_PRESSURE  CHRONIC DISEASE    FATIGUE     ALLERGY     WHEEZING  \
# count     276.000000       276.000000  276.000000  276.000000  276.000000
# mean        1.507246         1.521739    1.663043    1.547101    1.547101
# std         0.500856         0.500435    0.473529    0.498681    0.498681
# ...

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 276 entries, 0 to 283
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 276 non-null    int64
#  1   AGE                    276 non-null    int64
#  2   SMOKING                276 non-null    int64
#  3   YELLOW_FINGERS         276 non-null    int64
#  4   ANXIETY                276 non-null    int64
#  5   PEER_PRESSURE          276 non-null    int64
#  6   CHRONIC DISEASE        276 non-null    int64
#  7   FATIGUE                276 non-null    int64
#  8   ALLERGY                276 non-null    int64
#  9   WHEEZING               276 non-null    int64
#  10  ALCOHOL CONSUMING      276 non-null    int64
#  11  COUGHING               276 non-null    int64
#  12  SHORTNESS OF BREATH    276 non-null    int64
#  13  SWALLOWING DIFFICULTY  276 non-null    int64
#  14  CHEST PAIN             276 non-null    int64
# ...

# %%
new_data.describe(include = 'object')
# Out:
#        LUNG_CANCER
# count          276
# unique           2
# top            YES
# freq           238

# %%
new_data.hist(figsize=(50, 40), color = 'blue', edgecolor = 'black')
# Out:
# array([[<Axes: title={'center': 'GENDER'}>,
#         <Axes: title={'center': 'AGE'}>,
#         <Axes: title={'center': 'SMOKING'}>,
#         <Axes: title={'center': 'YELLOW_FINGERS'}>],
#        [<Axes: title={'center': 'ANXIETY'}>,
#         <Axes: title={'center': 'PEER_PRESSURE'}>,
#         <Axes: title={'center': 'CHRONIC DISEASE'}>,
#         <Axes: title={'center': 'FATIGUE '}>],
#        [<Axes: title={'center': 'ALLERGY '}>,
#         <Axes: title={'center': 'WHEEZING'}>,
#         <Axes: title={'center': 'ALCOHOL CONSUMING'}>,
#         <Axes: title={'center': 'COUGHING'}>],
#        [<Axes: title={'center': 'SHORTNESS OF BREATH'}>,
#         <Axes: title={'center': 'SWALLOWING DIFFICULTY'}>,
#         <Axes: title={'center': 'CHEST PAIN'}>, <Axes: >]], dtype=object)

# %%
new_data
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         1   69        1               2        2              1
# 1         1   74        2               1        1              1
# 2         0   59        1               1        1              2
# 3         1   63        2               2        2              1
# 4         0   63        1               2        1              1
# ..      ...  ...      ...             ...      ...            ...
# 279       0   59        1               2        2              2
# 280       0   59        2               1        1              1
# 281       1   55        2               1        1              1
# 282       1   46        1               2        2              1
# 283       1   60        1               2        2              1
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY  WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2        1         2                  2
# ...

# %%
new_data.rename(columns = {'ALLERGY ': 'ALLERGY'}, inplace = True)
# Out:
# <ipython-input-88-f38af6954ac4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data.rename(columns = {'ALLERGY ': 'ALLERGY'}, inplace = True)

# %%
new_data
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         1   69        1               2        2              1
# 1         1   74        2               1        1              1
# 2         0   59        1               1        1              2
# 3         1   63        2               2        2              1
# 4         0   63        1               2        1              1
# ..      ...  ...      ...             ...      ...            ...
# 279       0   59        1               2        2              2
# 280       0   59        2               1        1              1
# 281       1   55        2               1        1              1
# 282       1   46        1               2        2              1
# 283       1   60        1               2        2              1
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY  WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2        1         2                  2
# ...

# %%
new_data['ALLERGY'].unique()
# Out:
# array([1, 2])

# %% [markdown]
# Fixed the Naming error from the Dataset

# %%
import seaborn as sns

# %%
sns.pairplot(new_data)

# %%
new_data
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         1   69        1               2        2              1
# 1         1   74        2               1        1              1
# 2         0   59        1               1        1              2
# 3         1   63        2               2        2              1
# 4         0   63        1               2        1              1
# ..      ...  ...      ...             ...      ...            ...
# 279       0   59        1               2        2              2
# 280       0   59        2               1        1              1
# 281       1   55        2               1        1              1
# 282       1   46        1               2        2              1
# 283       1   60        1               2        2              1
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY  WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2        1         2                  2
# ...

# %%
new_data['LUNG_CANCER']=new_data['LUNG_CANCER'].map({'YES':1,'NO':0})
# Out:
# <ipython-input-96-6fe0b7f9e8f1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['LUNG_CANCER']=new_data['LUNG_CANCER'].map({'YES':1,'NO':0})

# %%
new_data
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         1   69        1               2        2              1
# 1         1   74        2               1        1              1
# 2         0   59        1               1        1              2
# 3         1   63        2               2        2              1
# 4         0   63        1               2        1              1
# ..      ...  ...      ...             ...      ...            ...
# 279       0   59        1               2        2              2
# 280       0   59        2               1        1              1
# 281       1   55        2               1        1              1
# 282       1   46        1               2        2              1
# 283       1   60        1               2        2              1
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY  WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2        1         2                  2
# ...

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 276 entries, 0 to 283
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 276 non-null    int64
#  1   AGE                    276 non-null    int64
#  2   SMOKING                276 non-null    int64
#  3   YELLOW_FINGERS         276 non-null    int64
#  4   ANXIETY                276 non-null    int64
#  5   PEER_PRESSURE          276 non-null    int64
#  6   CHRONIC DISEASE        276 non-null    int64
#  7   FATIGUE                276 non-null    int64
#  8   ALLERGY                276 non-null    int64
#  9   WHEEZING               276 non-null    int64
#  10  ALCOHOL CONSUMING      276 non-null    int64
#  11  COUGHING               276 non-null    int64
#  12  SHORTNESS OF BREATH    276 non-null    int64
#  13  SWALLOWING DIFFICULTY  276 non-null    int64
#  14  CHEST PAIN             276 non-null    int64
# ...

# %%
new_data.head()
# Out:
#    GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0       1   69        1               2        2              1
# 1       1   74        2               1        1              1
# 2       0   59        1               1        1              2
# 3       1   63        2               2        2              1
# 4       0   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY  WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2        1         2                  2         2
# 1                2         2        2         1                  1         1
# 2                1         2        1         2                  1         2
# 3                1         1        1         1                  2         1
# 4                1         1        1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  LUNG_CANCER
# ...

# %% [markdown]
# Index <br>
# 1) Gender (1 - Male, 0 - Female) <br>
# 2) Features (1 - No, 2 - Yes)

# %%
new_data.plot()
# Out:
# <Axes: >

# %%
new_data.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC DISEASE', 'FATIGUE ', 'ALLERGY', 'WHEEZING',
#        'ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH',
#        'SWALLOWING DIFFICULTY', 'CHEST PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
corr = new_data.corr()
features = corr.index
plt.figure(figsize = (20, 20))
ax = sns.heatmap(new_data[features].corr(), annot = True, cmap = 'YlGn')

# %%
from sklearn.feature_selection import mutual_info_classif
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
X = data.drop('LUNG_CANCER', axis=1)
y = data['LUNG_CANCER']

# %%
importance = mutual_info_classif(X, y)

# %%
feat_importance = pd.Series(importance, new_data.columns[0: len(new_data.columns)-1])

# %%
feat_importance.plot(kind = 'barh', color = 'teal')
# Out:
# <Axes: >

# %%
X
# Out:
#      ALLERGY  COUGHING
# 0          1         2
# 1          2         1
# 2          1         2
# 3          1         1
# 4          1         2
# ..       ...       ...
# 279        2         2
# 280        2         1
# 281        2         1
# 282        1         1
# 283        1         2
#
# [276 rows x 2 columns]

# %%
new_data.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC DISEASE', 'FATIGUE ', 'ALLERGY', 'WHEEZING',
#        'ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH',
#        'SWALLOWING DIFFICULTY', 'CHEST PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

X = new_data[['ALLERGY', 'COUGHING', 'ANXIETY', 'ALCOHOL CONSUMING']]
y = new_data['LUNG_CANCER']

regression_allergy = LinearRegression()
regression_coughing = LinearRegression()
# Fit the models to the data
regression_allergy.fit(X[['ALLERGY']], y)
regression_coughing.fit(X[['COUGHING']], y)

# Make predictions based on the models
y_pred_allergy = regression_allergy.predict(X[['ALLERGY']])
y_pred_coughing = regression_coughing.predict(X[['COUGHING']])

# Create separate scatter plots with regression lines for each feature
plt.figure(figsize=(10, 6))

# Scatter plot with regression line for ALLERGY
plt.scatter(X['ALLERGY'], y, label='ALLERGY Data', color='red')
plt.plot(X['ALLERGY'], y_pred_allergy, color='red', label='ALLERGY Regression Line')

# Scatter plot with regression line for COUGHING
plt.scatter(X['COUGHING'], y, label='COUGHING Data', color='blue')
plt.plot(X['COUGHING'], y_pred_coughing, color='blue', label='COUGHING Regression Line')



plt.xlabel('Features')
plt.ylabel('LUNG_CANCER')
plt.legend()
plt.show()
